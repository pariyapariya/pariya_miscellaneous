# %%
import pandas as pd
import json 
import requests

# %%
r = requests.get('https://api.census.gov/data/2017/abscs?get=GEO_ID,NAME,NAICS2017,NAICS2017_LABEL,INDGROUP,SEX,SEX_LABEL,ETH_GROUP,ETH_GROUP_LABEL,RACE_GROUP,RACE_GROUP_LABEL,VET_GROUP,VET_GROUP_LABEL,EMPSZFI,EMPSZFI_LABEL,YEAR,EMP,EMP_F&for=state:*&key=89c98e1ea78b5bd507e2a4c92e426d8069492b9e')

# df = pd.read_json(json.dumps(x))

# %%
x = r.json()

# %%
x

# %%
df = pd.read_json(json.dumps(x))

# %%
df.head(100)
# Out:
#               0            1          2                      3         4    5  \
# 0        GEO_ID         NAME  NAICS2017        NAICS2017_LABEL  INDGROUP  SEX
# 1   0400000US28  Mississippi      44-45           Retail trade      None  002
# 2   0400000US28  Mississippi      44-45           Retail trade      None  003
# 3   0400000US28  Mississippi      44-45           Retail trade      None  001
# 4   0400000US28  Mississippi      44-45           Retail trade      None  003
# ..          ...          ...        ...                    ...       ...  ...
# 95  0400000US28  Mississippi         00  Total for all sectors      None  001
# 96  0400000US28  Mississippi         00  Total for all sectors      None  001
# 97  0400000US28  Mississippi         00  Total for all sectors      None  001
# 98  0400000US28  Mississippi         00  Total for all sectors      None  001
# 99  0400000US28  Mississippi         00  Total for all sectors      None  001
#
#             6          7                                   8           9  \
# 0   SEX_LABEL  ETH_GROUP                     ETH_GROUP_LABEL  RACE_GROUP
# 1      Female        001                               Total          40
# 2        Male        020                            Hispanic          40
# 3       Total        020                            Hispanic          40
# 4        Male        001                               Total          40
# ..        ...        ...                                 ...         ...
# 95      Total        024  Other Hispanic, Latino, or Spanish          00
# 96      Total        024  Other Hispanic, Latino, or Spanish          00
# 97      Total        024  Other Hispanic, Latino, or Spanish          00
# 98      Total        024  Other Hispanic, Latino, or Spanish          00
# 99      Total        024  Other Hispanic, Latino, or Spanish          00
#
#                            10         11               12       13  \
# 0            RACE_GROUP_LABEL  VET_GROUP  VET_GROUP_LABEL  EMPSZFI
# 1   Black or African American        001            Total      001
# 2   Black or African American        001            Total      001
# 3   Black or African American        001            Total      001
# 4   Black or African American        001            Total      001
# ..                        ...        ...              ...      ...
# 95                      Total        001            Total      001
# 96                      Total        001            Total      611
# 97                      Total        001            Total      612
# 98                      Total        001            Total      620
# 99                      Total        001            Total      630
#
#                                14    15   16     17     18
# 0                   EMPSZFI_LABEL  YEAR  EMP  EMP_F  state
# 1                       All firms  2017  239   None     28
# 2                       All firms  2017    0      a     28
# 3                       All firms  2017    0      a     28
# 4                       All firms  2017  348   None     28
# ..                            ...   ...  ...    ...    ...
# 95                      All firms  2017  448   None     28
# 96        Firms with no employees  2017    0   None     28
# 97    Firms with 1 to 4 employees  2017   76   None     28
# 98    Firms with 5 to 9 employees  2017  190   None     28
# 99  Firms with 10 to 19 employees  2017    0      b     28
#
# [100 rows x 19 columns]

# %%
sex-df = df.loc[df['']  6]
