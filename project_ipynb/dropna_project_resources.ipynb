# %%
import pandas as pd

# %%
data = pd.read_csv('../Resources/PopByCounty_11-18.csv')

# %%
df = pd.DataFrame(data)

# %%
df.dropna()
# Out:
#       Unnamed: 0  GeoFips     County Name    2011    2012    2013    2014  \
# 0              0     1001     Autauga, AL   55208   54936   54713   54876
# 1              1     1003     Baldwin, AL  186540  190143  194886  199189
# 2              2     1005     Barbour, AL   27350   27174   26944   26758
# 3              3     1007        Bibb, AL   22747   22664   22516   22541
# 4              4     1009      Blount, AL   57554   57570   57611   57521
# ...          ...      ...             ...     ...     ...     ...     ...
# 3133        3133    56037  Sweetwater, WY   43981   45005   45162   44957
# 3134        3134    56039       Teton, WY   21414   21625   22318   22777
# 3135        3135    56041       Uinta, WY   20893   20994   20953   20827
# 3136        3136    56043    Washakie, WY    8448    8408    8414    8275
# 3137        3137    56045      Weston, WY    7142    7077    7137    7138
#
#         2015    2016    2017    2018
# 0      54838   55242   55443   55601
# ...

# %%
df.to_csv('../Resources/PopByCounty_11-18.csv')
